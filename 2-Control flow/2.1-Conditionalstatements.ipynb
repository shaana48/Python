# %% [markdown]
# ### CONDITIONAL STATEMENTS

# %%
## if statement
age=20
if age>=18:
    print("you are allowed to vote in the elections")
# Out:
# you are allowed to vote in the elections

# %%
## else statement
## The else statement executes a block of code if the condition in the if statement is False
age=16
if age>=18:
    print("You are eligible for voting")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
## elif statement
## The elif statement allows you to check multiple ondition. It stands for "else if"
age=20
if age<=13:
    print("You are a child")
elif age<18:
    print("You are a teenager")    
else:
    print("You are an adult")
# Out:
# You are an adult

# %%
## Nested conditional statement
## you can place one or more if,elif or else statements inside another if,elif or else statements to craete nested conditional statements

## number even , odd , negagitive

num=int(input("Enter the input "))
if num>=0:
    print("The number is positive")
    if num%2==0:
        print("The number is even")
    else:
        print("The number is odd")   
else:
    print("The number is zero or negative")
# Out:
# The number is positive
# The number is even

# %%
## Practical Examples

# Determine if a year is a leap year using Nested condition statement

year=int(input("Enter year"))
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print(f"{year} is a leap year")
        else:
            print(f"{year} is not a leap year")     
    else:
       print(f"{year } is a leap year")        
else:
    print(f"{year} is not a leap year")
# Out:
# 2024 is a leap year

# %%
## Determine the ticket prize based on age and whether the person is a student

age=int(input("Enter your age:"))
is_student=input("Are you a student? (yes/No)").lower()

if age<=5:
    print("Kids can enter free")
elif age<=12:
    if is_student == "yes":
        print("30")
    else:
        print("35")   
elif age<=21:
    if is_student == "yes":
        print("50")
    else:
        print("55")
elif age<=60:
    if is_student == "yes":
        print("75")
    else:
        print("100")
else:
    print("Not Allowed")
# Out:
# 35
