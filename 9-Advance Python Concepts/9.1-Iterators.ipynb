# %% [markdown]
# ##### ITERATORS
# Iterators areadvanced oython concepts that allow for EFFICIENT LOOPING and MEMEORY MANAGEMENT.Iteartors provide a way to acces elements of a collection sequentially without exposing the underlying structure.

# %%
my_list=[1,2,3,4,5]
for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
type(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
## Iterator
iterator=iter(my_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
iterator

# %% [markdown]
# It uses lazy loding technique.That basically means ritght now the my_list iterator is CREATED in some MEMEORY LOCATION bt it WILL NOT give us any ELEMETNS unless and UNTIO we ITERATE through that PARTICULAR ELEMENT.

# %%
## itetarte through the elements

next(iterator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[31], line 3
#       1 ## itetarte through the elements
# ----> 3 next(iterator)
#
# StopIteration:

# %% [markdown]
# here we got just one value here that we are accecssing the one value over here and its being able thats why it shows at first.you can excute again n again to get rest of the elements untill it shows a STOPITERATION ERROR after the execution of last element. this works with the help of next() function.

# %%
iterator=iter(my_list)

# %%
try:
    print(next(iterator))
except StopIteration:
    print("There are no elements in the iterator")
# Out:
# There are no elements in the iterator

# %%
my_stirng="Hello"
string_iterator=iter(my_stirng)

print(next(string_iterator))      # Output : H
print(next(string_iterator))      # Output : e
# Out:
# H
