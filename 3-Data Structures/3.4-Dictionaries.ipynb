# %% [markdown]
# ## DICTIONARIES

# %% [markdown]
# #####  Creating Dictionaries
# ##### Accessing Dictionary Elements
# ##### Modifying Dictionary Elements
# ##### Dictionary Methods
# ##### Iterating Over Dictionaries
# ##### Nested Dictionaries
# ##### Dictionary Comprehensions

# %% [markdown]
# ###### Dictionaries are unorderd collection of items.
# ###### They store in key-value pairs

# %%
## creating Dictionaries

empty_dict={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict=dict()
empty_dict
# Out:
# {}

# %%
student={"name":"Shana","age":32,"grade":24}
print(student)
print(type(student))
# Out:
# {'name': 'Shana', 'age': 32, 'grade': 24}
# <class 'dict'>

# %%
# Error

student={"name":"Shana","age":32,"grade":24,"name":24}
print(student)
# Out:
# {'name': 24, 'age': 32, 'grade': 24}

# %% [markdown]
# ##### Always use single keys
# ##### if you use a key twice it takes the value of the last time you put that key

# %%
## Accesing dicionary elements

student={"name":"Shana","age":32,"grade":"A"}
print(student)
# Out:
# {'name': 'Shana', 'age': 32, 'grade': 'A'}

# %%
## Accessing Dictionary Elements

print(student['grade'])
print(student['age'])
# Out:
# A
# 32

# %%
## Accessing using get() method

print(student.get('grade'))
print(student.get('f_name'))    ## non Existing
print(student.get('f_name',"Not Available"))     ## giving default value
# Out:
# A
# None
# Not Available

# %%
##Modifying Dictionaries
## Dictionaries are mutable,so you can add, update or delete elements

print(student)
# Out:
# {'name': 'Shana', 'age': 32, 'grade': 'A'}

# %%
student["age"]=33              # update value for the key
print(student)
# Out:
# {'name': 'Shana', 'age': 33, 'grade': 'A'}

# %%
student["address"]="India"     # adding a new key & value
print(student)
# Out:
# {'name': 'Shana', 'age': 33, 'grade': 'A', 'address': 'India'}

# %%
del student['grade']           # deleting the key & value
print(student)
# Out:
# {'name': 'Shana', 'age': 33, 'address': 'India'}

# %%
## Dictionary Mathods

keys=student.keys()            # get all the keys
print(keys)
values=student.values()        # get all the values
print(values)
items=student.items()        # get all key values pairs
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Shana', 33, 'India'])
# dict_items([('name', 'Shana'), ('age', 33), ('address', 'India')])

# %%
# shallow copy
student_copy=student
print(student)
print(student_copy)
# Out:
# {'name': 'Shana', 'age': 32, 'grade': 'A'}
# {'name': 'Shana', 'age': 32, 'grade': 'A'}

# %%
student["name"]="Shana1"
print(student)
print(student_copy)
# Out:
# {'name': 'Shana1', 'age': 32, 'grade': 'A'}
# {'name': 'Shana1', 'age': 32, 'grade': 'A'}

# %% [markdown]
# ##### Shallow Copy

# %% [markdown]
# ##### Shallow copy provides a different memeory location so that whenever we change one of the variable it should not impact the other one

# %%
student_copy1=student.copy()          # shallow copy
print(student_copy1)
print(student)
# Out:
# {'name': 'Shana1', 'age': 32, 'grade': 'A'}
# {'name': 'Shana1', 'age': 32, 'grade': 'A'}

# %%
student["name"]="Shana2"
print(student_copy1)
print(student)
# Out:
# {'name': 'Shana1', 'age': 32, 'grade': 'A'}
# {'name': 'Shana2', 'age': 32, 'grade': 'A'}

# %%
### iterating Over Dictionaries
## You can use loops to iterate over dictionaries, keys, values or items

# Iterating Over keys

for keys in student.keys():
   print(keys)
# Out:
# name
# age
# grade

# %%
# iterating ove values

for values in student.values():
    print(values)
# Out:
# Shana2
# 32
# A

# %%
# Iterate over key:value pairs

for key,value in student.items():
    print(f"{key}:{value}")
# Out:
# name:Shana2
# age:32
# grade:A

# %%
# Nested Dictionaries

students={
    "student1":{"name":"Shana","age":25},
    "student2":{"name":"Fthma","age":25.0}
}

# %%
## Access Nested Dictionaries
  
print(students["student2"]["name"])
print(students["student2"]["age"])
# Out:
# Fthma
# 25.0

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'Shana', 'age': 25}), ('student2', {'name': 'Fthma', 'age': 25.0})])

# %%
# Iterating over Nested Dictionaries

for student_id,student_info in students.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'Shana', 'age': 25}
# name:Shana
# age:25
# student2:{'name': 'Fthma', 'age': 25.0}
# name:Fthma
# age:25.0

# %%
## Dictionary Comprehension

square={x:x**2 for x in range (5)}
print(square)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
## Conditional  Dictionary Comprehension

evens={x:x**2 for x in range(10) if x%2==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## Examples

## USe a dictionary to count the frequency of elements in list

numbers=[1,2,2,3,3,3,4,4,4,4]
frequency={}

for number in numbers:
    if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
## Merge 2 dictionaries into one

dict1={"a":1,"b":2}
dict2={"b":3,"c":4}
merged_dict={ **dict1,**dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
