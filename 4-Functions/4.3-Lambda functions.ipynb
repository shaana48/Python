# %% [markdown]
# #### LAMBDA FUNCTIONS IN PYTHON

# %% [markdown]
# ##### Lambda functions are small anonymous functions defined using the lambda keyword.They can have any number of arguments but only one expression.Theyare commonly used for short operations or as arguments to higher-order functions

# %% [markdown]
# Anonymous Function is a function without name

# %%
# Syntax

lambda argument : expression
# Out:
# <function __main__.<lambda>(argument)>

# %%
def addition(a,b):
    return a+b

# %%
addition(2,8)
# Out:
# 10

# %%
addition=lambda a,b:a+b
print(type(addition))
print(addition(5,7))
# Out:
# <class 'function'>
# 12

# %% [markdown]
# Just a function that doesnt have  a name

# %%
def even(num):
    if num%2==0:
        return True
even(24)
# Out:
# True

# %%
even1=lambda num:num%2==0
even1(12)
# Out:
# True

# %%
def addition(x,y,z):
    return x+y+z

addition(12,13,14)
# Out:
# 39

# %%
addition1=lambda x,y,z:x+y+z
addition1(12,13,14)
# Out:
# 39

# %%
## map() - applies a function to all items in a list

numbers=[1,2,3,4,5]
def square(number):
    return number**2

square(8)
# Out:
# 64

# %%
list(map(lambda x:x**2,numbers))
# Out:
# [1, 4, 9, 16, 25]
